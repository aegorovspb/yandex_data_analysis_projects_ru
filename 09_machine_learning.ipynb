# %% [markdown]
# **Проект по курсу машинное обучение под названием «Культурист-датасаентист».**
#
# Цель проекта: разработать стратегию взаимодействия с клиентами в сети фитнес-центров «Культурист-датасаентист» на основе аналитических данных.
#
# Шаги исследования:
# * Шаг 1. Загрузка данных и подготовка их к анализу
# * Шаг 2. Анализ данных (EDA)
# * Шаг 3. Построение модели прогнозирования оттока клиентов
# * Шаг 4. Кластеризация клиентов
# * Шаг 5. Выводы и базовые рекомендации по работе с клиентами
#
#
# **Главная цель проекта** - провести анализ и разработать стратегию (дать реккомендации) по удержанию клиентов.

# %% [markdown]
# <h1>Структура проекта<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-подготовка-к-анализу" data-toc-modified-id="Загрузка-данных-и-подготовка-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных и подготовка к анализу</a></span><ul class="toc-item"><li><span><a href="#выводы-по-загрузке-данных-и-подготовке-к-анализу" data-toc-modified-id="выводы-по-загрузке-данных-и-подготовке-к-анализу-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>выводы по загрузке данных и подготовке к анализу</a></span></li></ul></li><li><span><a href="#Анализ-данных-(EDA)" data-toc-modified-id="Анализ-данных-(EDA)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных (EDA)</a></span><ul class="toc-item"><li><span><a href="#Выводы-по-средним-значениям" data-toc-modified-id="Выводы-по-средним-значениям-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Выводы по средним значениям</a></span></li><li><span><a href="#Выводы-для-средних-значений-по-признаку-отток-/-остался" data-toc-modified-id="Выводы-для-средних-значений-по-признаку-отток-/-остался-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Выводы для средних значений по признаку отток / остался</a></span></li><li><span><a href="#Построим-столбчатые-диаграммы:" data-toc-modified-id="Построим-столбчатые-диаграммы:-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Построим столбчатые диаграммы:</a></span></li><li><span><a href="#Построим-графики-распределения" data-toc-modified-id="Построим-графики-распределения-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Построим графики распределения</a></span></li><li><span><a href="#Выводы-по-графикам" data-toc-modified-id="Выводы-по-графикам-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Выводы по графикам</a></span></li><li><span><a href="#Матрица-корреляции" data-toc-modified-id="Матрица-корреляции-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Матрица корреляции</a></span></li><li><span><a href="#Выводы-по-матрице-корреляции" data-toc-modified-id="Выводы-по-матрице-корреляции-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Выводы по матрице корреляции</a></span></li><li><span><a href="#Общие-выводы-по-EDA-анализу" data-toc-modified-id="Общие-выводы-по-EDA-анализу-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Общие выводы по EDA анализу</a></span></li></ul></li><li><span><a href="#Модель-прогнозирования-оттока-клиентов" data-toc-modified-id="Модель-прогнозирования-оттока-клиентов-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель прогнозирования оттока клиентов</a></span><ul class="toc-item"><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Вывод-по-сравнению-моделей" data-toc-modified-id="Вывод-по-сравнению-моделей-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Вывод по сравнению моделей</a></span></li></ul></li><li><span><a href="#Сделайте-кластеризацию-клиентов" data-toc-modified-id="Сделайте-кластеризацию-клиентов-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Сделайте кластеризацию клиентов</a></span><ul class="toc-item"><li><span><a href="#Выводы-по-дендограмме" data-toc-modified-id="Выводы-по-дендограмме-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Выводы по дендограмме</a></span></li><li><span><a href="#Постройте-распределения-признаков-для-кластеров.-Можно-ли-что-то-заметить-по-ним?" data-toc-modified-id="Постройте-распределения-признаков-для-кластеров.-Можно-ли-что-то-заметить-по-ним?-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Постройте распределения признаков для кластеров. Можно ли что-то заметить по ним?</a></span></li><li><span><a href="#Выводы-по-кластерам" data-toc-modified-id="Выводы-по-кластерам-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Выводы по кластерам</a></span></li><li><span><a href="#построим-графики-распределения-с-учетом-кластеров" data-toc-modified-id="построим-графики-распределения-с-учетом-кластеров-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>построим графики распределения с учетом кластеров</a></span></li><li><span><a href="#построим-столбчатые-диаграммы-с-учетом-кластеров" data-toc-modified-id="построим-столбчатые-диаграммы-с-учетом-кластеров-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>построим столбчатые диаграммы с учетом кластеров</a></span></li></ul></li><li><span><a href="#Выводы-и-базовые-реккомендации" data-toc-modified-id="Выводы-и-базовые-реккомендации-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выводы и базовые реккомендации</a></span></li></ul></div>

# %% [markdown]
# Чек лист:
# - [x] Откройте данные
# - [x] Посмотрите на датасет: есть ли в нем отсутствующие признаки, изучите средние значения и стандартные отклонения (пригодится метод describe());
# - [x] Посмотрите на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался (воспользуйтесь методом groupby());
# - [x] Постройте столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);
# - [x] Постройте матрицу корреляций и отобразите её.

# %% [markdown]
# Постройте модель прогнозирования оттока клиентов
# - [x] Разбейте данные на обучающую и валидационную выборку функцией train_test_split().
# - [x] Обучите модель на train-выборке двумя способами:
# - [x] логистической регрессией,
# - [x] случайным лесом.
# - [x] Оцените метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравните по ним модели. Какая модель показала себя лучше на основании метрик?

# %% [markdown]
# Сделайте кластеризацию клиентов
# - [x] Стандартизируйте данные.
# - [x] Постройте матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисуйте дендрограмму. Внимание: отрисовка дендрограммы может занять время! На основании полученного графика предположите, какое количество кластеров можно выделить.
# - [x] Обучите модель кластеризации на основании алгоритма K-Means и спрогнозируйте кластеры клиентов. Договоримся за число кластеров принять n=5, чтобы ваши результаты можно было сравнивать с результатами остальных студентов. Однако, конечно, в жизни никто не скажет вам правильный ответ, и решение остаётся за вами (на основании изучения графика из предыдущего пункта).
# - [x] Посмотрите на средние значения признаков для кластеров. Можно ли сразу что-то заметить?
# - [x] Постройте распределения признаков для кластеров. Можно ли что-то заметить по ним?
# - [x] Для каждого полученного кластера посчитайте долю оттока (методом groupby()). Отличаются ли они по доле оттока? Какие кластеры склонны к оттоку, а какие — надёжны?

# %% [markdown]
# ## Загрузка данных и подготовка к анализу

# %%
# загрузим библиотеки
import pandas as pd

# графики
import seaborn as sns
import matplotlib.pyplot as plt


# работа с массивами данных, округление
import numpy as np

# логистическая регрессия
from sklearn.linear_model import LogisticRegression
# случайный лес
from sklearn.ensemble import RandomForestClassifier

# проверка модели
from sklearn.model_selection import train_test_split

# метрики классификации. Работа с метками
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# стандартизируем данные
from sklearn.preprocessing import StandardScaler

# Обучение без учителя: кластеризация K-Means
from sklearn.cluster import KMeans

# нарисуем дендограмму в Python
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
# получение названия файла БД при загрузке
import os

# загрузка БД с сервера или ПК
# attempt_1 - путь и название файла для загрузки с сервера
# attempt_2 - путь и название файла для загрузки с ПК

attempt_1 ='https://code.s3.yandex.net/datasets/gym_churn.csv'
attempt_2 ='C://yandex_data_sets/09_gym_churn.csv'

# берем название файла из указанного пути
name_os_data = os.path.basename(attempt_1)
print('File name:',name_os_data)

# обработка ошибок при загрузке
# функция загрузки данных
def loading_data(attempt_df_1, attempt_df_2):
    
    # обработка ошибки при загрузке с сервера
    try:
        df = pd.read_csv(attempt_df_1) # , sep='\t'
        print(name_os_data, 'has been downloaded from the server')
    except IOError:
        print('HTTP Error 404: File Not Found')
        
        # обработка ошибки при загрузке с локального диска
        try:
            df = pd.read_csv(attempt_df_2)
            print(name_os_data, 'has been downloaded from the local host')
        except IOError:
            print('Local Error: File Not Found')
    return df

df = loading_data(attempt_1, attempt_2)
# Out:
# File name: gym_churn.csv
# gym_churn.csv has been downloaded from the server

# %%
#распечатаем его размер и первые 5 строк
display(df.shape)
display(df.head())

#посмотрим на сводную информацию о наборе данных
display(df.info())
# Out:
# (4000, 14)
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
# ...

# %% [markdown]
# В данных нет пропусков, тип данных соответсвует описанию.
# Для исключения ошибок изменим регистр названия столбцов.

# %%
# названия столбцов приводим к нижнему регистру
df.columns = df.columns.str.lower()
df.head(3)
# Out:
#    gender  near_location  partner  promo_friends  phone  contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
#
#    group_visits  age  avg_additional_charges_total  month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
#
#    lifetime  avg_class_frequency_total  avg_class_frequency_current_month  \
# 0         3                   0.020398                           0.000000
# 1         7                   1.922936                           1.910244
# 2         2                   1.859098                           1.736502
#
#    churn
# 0      0
# 1      0
# 2      0

# %% [markdown]
# ### выводы по загрузке данных и подготовке к анализу

# %% [markdown]
# - данные загружены корректно
# - проблем и ошибок в данных не обнаружено
# - изменены названия столбцов

# %% [markdown]
# ## Анализ данных (EDA)

# %%
# округлим данные для лучшего обзора
pd.set_option('display.precision',2)

display(df.describe())
# Out:
#         gender  near_location  partner  promo_friends   phone  \
# count  4000.00        4000.00  4000.00        4000.00  4000.0
# mean      0.51           0.85     0.49           0.31     0.9
# std       0.50           0.36     0.50           0.46     0.3
# min       0.00           0.00     0.00           0.00     0.0
# 25%       0.00           1.00     0.00           0.00     1.0
# 50%       1.00           1.00     0.00           0.00     1.0
# 75%       1.00           1.00     1.00           1.00     1.0
# max       1.00           1.00     1.00           1.00     1.0
#
#        contract_period  group_visits      age  avg_additional_charges_total  \
# count          4000.00       4000.00  4000.00                       4000.00
# mean              4.68          0.41    29.18                        146.94
# std               4.55          0.49     3.26                         96.36
# min               1.00          0.00    18.00                          0.15
# ...

# %% [markdown]
# ### Выводы по средним значениям

# %% [markdown]
# Выводы:
# - genre (пол) - Мужчин и женщин примерно поровну.
# - near_ (проживание рядом) - В основном клиенты проживают рядом
# - partner (сотрудник компании) - Примерно половина клиентов от сотрудничающих компаний
# - promo_fr (промо-код от друга) - 31% пришли по промокоду от друга
# - phone (телефон) - 90% указан телефон
# - contract (длит абонемента) - в среднем 4.68 месяца, меньше 6
# - group (групп занятия)- 41% посещают
# - age (возраст) - 29 лет в среднем
# - avg_add (сумм выручка от др услуг) - 147р в среднем
# - month_to_end (срок до оконч тек обонем) - до окончания абонемента 4.32 месяца в среднем
# - lifetime (время с первого обращения) - 3.72 месяца
# - avg_class_total (среднее посещение всего) - 1.88 посещения в месяц в течении года, довольно странно меньше двух посещений в месяц.
# - avg_class_month (среднее посещение в месяц) - 1.77 среднее посещение в посл месяц
# - churn (факт оттока в тек месяце) - 27% перешли в группу отток клиентов
#
# Основные замечания: показатель оттока 27% достаточно высокий т.к. если клиенты в таком количестве покидают клуб, то необходимо в таком же количестве привлекать новых клиентов.

# %% [markdown]
# Посмотрите на средние значения признаков в двух группах

# %%
# абсолютные показатели
df.groupby('churn').count()
# Out:
#        gender  near_location  partner  promo_friends  phone  contract_period  \
# churn
# 0        2939           2939     2939           2939   2939             2939
# 1        1061           1061     1061           1061   1061             1061
#
#        group_visits   age  avg_additional_charges_total  \
# churn
# 0              2939  2939                          2939
# 1              1061  1061                          1061
#
#        month_to_end_contract  lifetime  avg_class_frequency_total  \
# churn
# 0                       2939      2939                       2939
# 1                       1061      1061                       1061
#
#        avg_class_frequency_current_month
# churn
# 0                                   2939
# 1                                   1061

# %%
# относительные показатели
df.groupby('churn').mean()
# Out:
#        gender  near_location  partner  promo_friends  phone  contract_period  \
# churn
# 0        0.51           0.87     0.53           0.35    0.9             5.75
# 1        0.51           0.77     0.36           0.18    0.9             1.73
#
#        group_visits    age  avg_additional_charges_total  \
# churn
# 0              0.46  29.98                        158.45
# 1              0.27  26.99                        115.08
#
#        month_to_end_contract  lifetime  avg_class_frequency_total  \
# churn
# 0                       5.28      4.71                       2.02
# 1                       1.66      0.99                       1.47
#
#        avg_class_frequency_current_month
# churn
# 0                                   2.03
# 1                                   1.04

# %% [markdown]
# ### Выводы для средних значений по признаку отток / остался

# %% [markdown]
# Выводы для средних значений:
# - genre (пол) - примерно поровну
# - near_ (проживание рядом) - в оттоке по сравнению с теми кто остается больше тех кто живет далеко, логично
# - partner (сотрудник компании) - в оттоке таких меньше чем тех кто остался
# - promo_fr (промо-код от друга) - таких мало на оттоке
# - phone (телефон) - 90% и там и там
# - contract (длит абонемента) - на оттоке короткий контракт, то же логично люди с коротким контарктом прогнозируют уход
# - group (групп занятия) - на оттоке меньше посещают групповые занятия
# - age (возраст) - на оттоке немного младше (27 против 30 лет у тех кто остается)
# - avg_add (сумм выручка от др услуг) - на оттоке немного меньше 115уе против 158 у тех кто остается
# - month_to_end (срок до оконч тек абонем) - в среднем 1.66 против 5.28, начение сильно соррелируется с длительностью контракта
# - lifetime (время с первого обращения) - меньше 1 месяца против 4.7 у тех кто остается
# - avg_class_total (среднее посещение всего) - 1.47 против 2.02 у тех кто остается
# - avg_class_month (среднее посещение в месяц) - 1.04 против 2.02 т.е. падает
# - churn (факт оттока в тек месяце)
#
# Основные выводы:
# Высокая корреляция по продолжительности аббонемента, очевидный факт, человек который берет абонемент на месяц с большой вероятностью покинет клуб. Так же можно обратить внимание на факт, что у тех кто в оттоке низкий показатель по приходу от друзей, это так же совершенно логично: нет друзей, высокая вероятность покинуть клуб. Других очевидных взаимосвязей, таких как пол, телефон, возраст не обнаружено.

# %% [markdown]
# ### Построим столбчатые диаграммы:

# %%
df_columns = df.columns
print(df_columns)
# Out:
# Index(['gender', 'near_location', 'partner', 'promo_friends', 'phone',
#        'contract_period', 'group_visits', 'age',
#        'avg_additional_charges_total', 'month_to_end_contract', 'lifetime',
#        'avg_class_frequency_total', 'avg_class_frequency_current_month',
#        'churn'],
#       dtype='object')

# %% [markdown]
# ### Построим графики распределения

# %%
for index in df_columns:
    plt.figure(figsize=(5, 5))
    sns.boxplot(x = 'churn', y = df[index], data = df)
    plt.show()

# %% [markdown]
# ### Выводы по графикам

# %% [markdown]
# В целом выводы по графика подтверждаю наблюдения по средним величинам по двум группам:
#     Высокая корреляция по продолжительности аббонемента, очевидный факт, человек который берет абонемент на месяц с большой вероятностью покинет клуб. Так же можно обратить внимание на факт, что у тех кто в оттоке низкий показатель по приходу от друзей, это так же совершенно логично: нет друзей, высокая вероятность покинуть клуб

# %% [markdown]
# ### Матрица корреляции

# %%
cm = df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(cm, annot = True)
plt.show()

# %% [markdown]
# ### Выводы по матрице корреляции

# %% [markdown]
# В целом выводы повторяют озвученное ранее:
# - очень высока корреляци между периодом абонемента и количеством месяцев до окончания контракта
# - высокая корреляция между средняя частота посещений в неделю за все время с начала действия абонемента и  средняя частота посещений в неделю за предыдущий месяц
# - достаточно высока корреляция между сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента) и  факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента) т.е. клиетны от компаний партнеров часто приходят вместе с друзьями

# %% [markdown]
# Результат 0.97 и 0.95 с высокой корреляцией, эти параметры могут отрицательно влияеть на обучаемость линейной модели, для проверки влияния этих параметров нужно удалить эти данные и проверить будут ли показания можели лучше после их удаления. Однако, мы уже сравнили линейную модель с другой моделью и в результате сравнения стало понятно, что линейная можель несмотря на мультиколлинеарные признаки работает хорошо, во вторых еще при обзоре данных было понятно, что между частой посещения в неделю и за все время будет очень высокая корреляция как и между периодом абонемента и количеством месяцев до завершения абонемента, т.е. эти данные важны для всего анализ а значит удалять их не следует.

# %% [markdown]
# ### Общие выводы по EDA анализу

# %% [markdown]
# В ходе анализа рассмотрены средние значения, построены графики распределения и столбчатая диаграмма, построена матрица корреляции. Обнаружены корреляции между разными признаками.

# %% [markdown]
# ## Модель прогнозирования оттока клиентов

# %% [markdown]
# Постройте модель бинарной классификации клиентов, где целевой признак — факт оттока клиента в следующем месяце:

# %% [markdown]
# Разбейте данные на обучающую и валидационную выборку функцией train_test_split().

# %% [markdown]
# ### Логистическая регрессия

# %%
# стандартизируем данные
sc = StandardScaler()
#X_sc = sc.fit_transform(df)

# %%
X = df.drop('churn', axis = 1)
y = df['churn']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model = LogisticRegression(solver='liblinear')

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
predictions = model.predict(X_test)
probabilities =  model.predict_proba(X_test)[:,1]

# %%
# выведите значения predictions и probabilities на экран
#print(predictions)
#print(probabilities)

# %%
# выведите все изученные метрики для полученного прогноза
print('Доля правильных ответов (accuracy): {:.2f}'.format(accuracy_score(y_test, predictions)))
print('Точность (precision): {:.2f}'.format(precision_score(y_test, predictions)))
print('Полнота (recall): {:.2f}'.format(recall_score(y_test, predictions)))
print('F1_score: {:.2f}'.format(f1_score(y_test, predictions)))
# Out:
# Доля правильных ответов (accuracy): 0.93
# Точность (precision): 0.86
# Полнота (recall): 0.83
# F1_score: 0.85

# %% [markdown]
# ### Случайный лес

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_st = scaler.transform(X_train)
X_test_st = scaler.transform(X_test)

rf_model = RandomForestClassifier(n_estimators = 100, random_state = 0) 
rf_model.fit(X_train_st, y_train)
rf_predictions = rf_model.predict(X_test_st) 
rf_probabilities = rf_model.predict_proba(X_test_st)[:,1]

# %%
# выведите все изученные метрики для полученного прогноза Random Foest
print('Доля правильных ответов (accuracy): {:.2f}'.format(accuracy_score(y_test, rf_predictions)))
print('Точность (precision): {:.2f}'.format(precision_score(y_test, rf_predictions)))
print('Полнота (recall): {:.2f}'.format(recall_score(y_test, rf_predictions)))
print('F1_score: {:.2f}'.format(f1_score(y_test, rf_predictions)))
# Out:
# Доля правильных ответов (accuracy): 0.92
# Точность (precision): 0.84
# Полнота (recall): 0.81
# F1_score: 0.83

# %% [markdown]
# ### Вывод по сравнению моделей

# %% [markdown]
# Логистическая регрессия по параметрам немного лучше.

# %% [markdown]
# ## Сделайте кластеризацию клиентов

# %%
# удалим churn
df_no_c = df.drop(['churn'], axis=1)

# список столбцов
df_columns_list_no_c = df_no_c.columns

# стандартизируем данные
sc = StandardScaler()
X_sc = sc.fit_transform(df_no_c)

# %%
linked = linkage(df_no_c, method = 'ward')

# %%
# после этого выполним стандартизацию и передадим получившуюся стандартизированную
# таблицу в качестве параметра функции linkage(). Чтобы диаграмма получилась показательной, лучше передать параметру method значение 'ward':


# В переменной linked сохранена таблица «связок» между объектами. Её можно визуализировать как дендрограмму:

linked = linkage(X_sc, method = 'ward') 
plt.figure(figsize=(15, 10))  
dendrogram(linked, orientation='top')
plt.title('Дендограмма клиентов')
plt.show()

# %% [markdown]
# ### Выводы по дендограмме

# %% [markdown]
# На основе дендограммы и общепринятого возьмем число кластеров равное 5

# %%
km = KMeans(n_clusters=5, random_state=0) # задаём число кластеров, равное 5, и фиксируем значение random_state для воспроизводимости результата
labels = km.fit_predict(X_sc) # применяем алгоритм к данным и формируем вектор кластеров
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# сохраняем метки кластера в поле нашего датасета
df['cluster_km'] = labels

# %% [markdown]
# ### Постройте распределения признаков для кластеров. Можно ли что-то заметить по ним?

# %%
# посмотрим абсолютные количества по кластерам
df.groupby(['cluster_km'])['gender'].count()
# Out:
# cluster_km
# 0    1010
# 1     385
# 2     505
# 3    1262
# 4     838
# Name: gender, dtype: int64

# %%
# посмотрим абсолютные количества по кластерам
df.groupby(['cluster_km']).count().T
# Out:
# cluster_km                            0    1    2     3    4
# gender                             1010  385  505  1262  838
# near_location                      1010  385  505  1262  838
# partner                            1010  385  505  1262  838
# promo_friends                      1010  385  505  1262  838
# phone                              1010  385  505  1262  838
# contract_period                    1010  385  505  1262  838
# group_visits                       1010  385  505  1262  838
# age                                1010  385  505  1262  838
# avg_additional_charges_total       1010  385  505  1262  838
# month_to_end_contract              1010  385  505  1262  838
# lifetime                           1010  385  505  1262  838
# avg_class_frequency_total          1010  385  505  1262  838
# avg_class_frequency_current_month  1010  385  505  1262  838
# churn                              1010  385  505  1262  838

# %%
# выводим статистику по средним значениям наших признаков по кластеру
clusters = df.groupby(['cluster_km']).mean().T
display(clusters)
# Out:
# cluster_km                              0       1       2       3       4
# gender                               0.50    0.52    0.50    0.49    0.56
# near_location                        0.96    0.86    0.00    1.00    0.98
# partner                              0.78    0.47    0.46    0.35    0.36
# promo_friends                        0.57    0.31    0.08    0.24    0.23
# phone                                1.00    0.00    1.00    1.00    1.00
# contract_period                     10.89    4.79    2.35    1.95    2.67
# group_visits                         0.54    0.43    0.22    0.34    0.47
# age                                 29.98   29.30   28.48   28.17   30.13
# avg_additional_charges_total       160.76  143.96  135.46  131.62  161.66
# month_to_end_contract                9.95    4.48    2.20    1.86    2.46
# lifetime                             4.74    3.92    2.81    2.44    4.90
# avg_class_frequency_total            1.98    1.85    1.66    1.25    2.85
# ...

# %% [markdown]
# ### Выводы по кластерам

# %% [markdown]
# - пол по всем кластерам распределился примерно одинаково
# - самые показательные группы 0 и 4 с самым низким оттоком, 2 и 3 с самым высоким оттоком
# - в 4 кластере самая высокая сумма выручки от других услуг 161,66 на третьем месте, но с неболшим разрывом от первых двух (160,76 и 143.96)
# - в 3 кластере самый короткий месяц до завершения контракта: 1.25 там же самый высокий отток
# - высокий lifetime 4.90 в 4 группе, там же один из самых низких оттоков, это подтверждается и 0 группой, длинный lifetime низкая вероятность ухода в отток.
# - по 0 и 4 группе самый высокий доход от продажи прочих услуг
# - по 2 и 3 кластеру самый высокий отток, при этом у них диаметрально разные показатели по near_location, можно сделать предположение, что расположение не иметт прямого отношения к оттоку, это же видно в матрице корреляции
# - в 0 группе с самым низким оттоком высокий показатель принадлежности к компании партнеру и программе promo_friends
# - прослеживаетс взаимосвязь между частотой посещений в неделю и оттоком, чем чаще посещают клуб тем меньше вероятность попасть в отток

# %% [markdown]
# ### построим графики распределения с учетом кластеров

# %% [markdown]
# - группы 0 и 4 с низким оттоком
# - группы 2 и 3 с высоким оттоком

# %%
for index in df_columns:
    plt.figure(figsize=(5, 5))
    sns.boxplot(x = 'cluster_km', y = df[index], data = df)
    plt.show()

# %% [markdown]
# ### построим столбчатые диаграммы с учетом кластеров

# %% [markdown]
# - группы 0 и 4 с низким оттоком
# - группы 2 и 3 с высоким оттоком

# %%
 for index in df_columns:
    plt.figure(figsize=(5, 5))
    sns.countplot(x = df[index], hue='cluster_km', data=df)
    plt.title(index)
    plt.show()

# %% [markdown]
# Используем countplot для большей информативности, уберем неинформативные графики.

# %%
# используем countplot для большей информативности, уберем неинформативные графики

numeric_columns = ['age', 'avg_additional_charges_total', 'month_to_end_contract', 'lifetime',
                   'avg_class_frequency_total', 'avg_class_frequency_current_month']
for column in numeric_columns:
    plt.figure(figsize=(12, 4))
    sns.histplot(x=column, hue="cluster_km", data=df, kde=True, palette="bright", element="step")
    plt.title(column)
    plt.show()

# %% [markdown]
# ## Выводы и базовые реккомендации

# %% [markdown]
# - графики по кластерам подтверждают главную гипотезу о том, что в отток чаще всего попадают люди с коротким абонементом
# - прямой зависимости между оттоком и расположением нет
# - прямой зависимости между компаниями партнерами и приходом с другом нет, хотя показатели в группах с низким оттоком эти показатели лучше
# - наблюдается взаимосвязь, чем дольше клиент ходит в клуб тем ниже вероятность, что он попадет в отток

# %% [markdown]
# Общие реккомендации:
# - уделить особое внимание клиентам с коротким абонементом
# - пытаться повышать количество средних посещений для этих клиентов в первую очередь, т.к. наблюдается взаимосвязь, чем чаще в среднем клиент ходит в клуб, тем ниже вероятность, что этот клиент попадет в отток
# - прямой зависимости между посещением групповых занятий и попаданием в отток не обнаружено, однако для кластера с высоким оттоком 0.44 есть самая низкая посещаемость групповых занятий 0.22, клиентам с короткими абонементами можно предалгать дополнительные акции на посещение групповых зянятий
# - не обнаружено прямой взаимосвязи между расположением клиентом и попаданием в отток, необходимо уделять одинаковое внимание клиентам вне зависимости от их расположения
